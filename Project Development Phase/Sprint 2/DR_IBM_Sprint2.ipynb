# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {
      "provenance": []
    },
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    },
    "language_info": {
      "name": "python"
    }
  },
  "cells": [
    {
      "cell_type": "code",
      "source": [
        "from google.colab import drive\n",
        "drive.mount('/content/drive')"
      ],
      "metadata": {
        "id": "zLesVkvRQiZU",
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "outputId": "2ac7bfb5-10e6-4d62-c716-7398800a9a4f"
      },
      "execution_count": 1,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Mounted at /content/drive\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "import os\n",
        "import numpy as np\n",
        "import matplotlib.pyplot as plt\n",
        "\n",
        "images = \"/content/drive/MyDrive/archive (3).zip (Unzipped Files)/IBM Dataset/gaussian_filtered_images\"\n",
        "\n",
        "folders = os.listdir(images)\n",
        "print(folders)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "c753b-tyjxE1",
        "outputId": "750306e7-14f1-4e80-ea24-a9991ad99df8"
      },
      "execution_count": 2,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "['Mild', 'Moderate', 'No_DR', 'Proliferate_DR', 'Severe']\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "image_data = []\n",
        "labels = []\n",
        "label_dict = {\n",
        "    'No_DR':1,\n",
        "    'Mild':2,\n",
        "    'Moderate':3,\n",
        "    'Proliferate_DR':4,\n",
        "    'Severe':5\n",
        "\n",
        "}"
      ],
      "metadata": {
        "id": "arIOwNihj61t"
      },
      "execution_count": 3,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "trainPath=r\"/content/drive/MyDrive/archive (3).zip (Unzipped Files)/IBM Dataset/gaussian_filtered_images\"\n",
        "testPath=r\"/content/drive/MyDrive/archive (3).zip (Unzipped Files)/IBM Dataset/gaussian_filtered_images\""
      ],
      "metadata": {
        "id": "DGUWBEoOlp2Y"
      },
      "execution_count": 4,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img\n",
        "from glob import glob\n",
        "import numpy as np\n",
        "import matplotlib.pyplot as plt"
      ],
      "metadata": {
        "id": "ZfoFxp0-lv0M"
      },
      "execution_count": 6,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "import tensorflow as tf\n",
        "from keras_preprocessing.image import load_img\n",
        "from keras_preprocessing.image import img_to_array\n",
        "from keras_preprocessing.image import array_to_img\n",
        "import PIL\n",
        "import tensorflow as tf\n",
        "import pathlib\n",
        "import matplotlib.pyplot as plt\n",
        "train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255,\n",
        "                                   shear_range=0.1,\n",
        "                                   zoom_range=0.1,\n",
        "                                   horizontal_flip=True)\n",
        "\n",
        "test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255,\n",
        "                                   shear_range=0.1,\n",
        "                                   zoom_range=0.1,\n",
        "                                   horizontal_flip=True)\n",
        "training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/archive (3).zip (Unzipped Files)/IBM Dataset/gaussian_filtered_images',\n",
        "                                                 target_size = (299, 299),\n",
        "                                                 batch_size = 32,\n",
        "                                                 class_mode = 'categorical')\n",
        "test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/archive (3).zip (Unzipped Files)/IBM Dataset/gaussian_filtered_images',\n",
        "                                                 target_size = (299, 299),\n",
        "                                                 batch_size = 32,\n",
        "                                                 class_mode = 'categorical')"
      ],
      "metadata": {
        "id": "XNjTXua5lz4K",
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "outputId": "2fa363eb-52ba-41c6-be9a-7b47023dee07"
      },
      "execution_count": 7,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Found 3672 images belonging to 5 classes.\n",
            "Found 3672 images belonging to 5 classes.\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "from tensorflow.keras.models import Sequential\n",
        "from tensorflow.keras.layers import Conv2D\n",
        "from tensorflow.keras.layers import MaxPooling2D\n",
        "from tensorflow.keras.layers import Flatten\n",
        "from tensorflow.keras.layers import Dense\n",
        "from tensorflow.keras.models import Model, Sequential\n",
        "from tensorflow.keras.preprocessing.image import ImageDataGenerator\n",
        "from tensorflow.keras.optimizers import SGD\n",
        "from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D , Flatten\n",
        "from tensorflow.keras.losses import categorical_crossentropy\n",
        "from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping\n",
        "from tensorflow.keras import metrics"
      ],
      "metadata": {
        "id": "hsxhXPgdl15t"
      },
      "execution_count": 31,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "from tensorflow.keras.applications.vgg16 import VGG16\n",
        "from tensorflow.keras.applications.vgg16 import preprocess_input\n",
        "vgg16 = VGG16(weights='imagenet')\n",
        "vgg16.summary()\n",
        "\n",
        "x  = vgg16.get_layer('fc2').output\n",
        "prediction = Dense(5, activation='softmax', name='predictions')(x)\n",
        "\n",
        "model = Model(inputs=vgg16.input, outputs=prediction)"
      ],
      "metadata": {
        "id": "fD1rbqoemLq_",
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "outputId": "9fd10b79-d41f-44d6-819a-4379712e07b7"
      },
      "execution_count": 32,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Model: \"vgg16\"\n",
            "_________________________________________________________________\n",
            " Layer (type)                Output Shape              Param #   \n",
            "=================================================================\n",
            " input_5 (InputLayer)        [(None, 224, 224, 3)]     0         \n",
            "                                                                 \n",
            " block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792      \n",
            "                                                                 \n",
            " block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928     \n",
            "                                                                 \n",
            " block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0         \n",
            "                                                                 \n",
            " block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856     \n",
            "                                                                 \n",
            " block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584    \n",
            "                                                                 \n",
            " block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0         \n",
            "                                                                 \n",
            " block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168    \n",
            "                                                                 \n",
            " block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080    \n",
            "                                                                 \n",
            " block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080    \n",
            "                                                                 \n",
            " block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0         \n",
            "                                                                 \n",
            " block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160   \n",
            "                                                                 \n",
            " block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808   \n",
            "                                                                 \n",
            " block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808   \n",
            "                                                                 \n",
            " block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0         \n",
            "                                                                 \n",
            " block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808   \n",
            "                                                                 \n",
            " block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808   \n",
            "                                                                 \n",
            " block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808   \n",
            "                                                                 \n",
            " block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0         \n",
            "                                                                 \n",
            " flatten (Flatten)           (None, 25088)             0         \n",
            "                                                                 \n",
            " fc1 (Dense)                 (None, 4096)              102764544 \n",
            "                                                                 \n",
            " fc2 (Dense)                 (None, 4096)              16781312  \n",
            "                                                                 \n",
            " predictions (Dense)         (None, 1000)              4097000   \n",
            "                                                                 \n",
            "=================================================================\n",
            "Total params: 138,357,544\n",
            "Trainable params: 138,357,544\n",
            "Non-trainable params: 0\n",
            "_________________________________________________________________\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "checkpoint = ModelCheckpoint(\"ibm_model.h5\", monitor='val_accuracy', verbose=1, \n",
        "                             save_best_only=True, save_weights_only=False, mode='auto')\n",
        "early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='auto')"
      ],
      "metadata": {
        "id": "GsETH7EAyGG5"
      },
      "execution_count": 33,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "for layer in model.layers:\n",
        "  layer.trainable  = False  "
      ],
      "metadata": {
        "id": "zb6yVZ4OmVHK"
      },
      "execution_count": 34,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "from keras import losses \n",
        "from keras import optimizers \n",
        "from keras import metrics "
      ],
      "metadata": {
        "id": "Y88D6nJvmatF"
      },
      "execution_count": 35,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "model.compile(loss = 'mean_squared_error',  \n",
        "   optimizer = 'sgd', metrics = [metrics.categorical_accuracy])"
      ],
      "metadata": {
        "id": "alxJXppy5LRs"
      },
      "execution_count": 36,
      "outputs": []
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {
        "colab": {
          "background_save": true,
          "base_uri": "https://localhost:8080/"
        },
        "id": "92h-avlJzrX0",
        "outputId": "b87f2c9d-9a95-4d26-8f99-477300cd5e5b"
      },
      "outputs": [
        {
          "name": "stdout",
          "output_type": "stream",
          "text": [
            "25/25 [==============================] - ETA: 0s - loss: 0.1621 - categorical_accuracy: 0.0938  "
          ]
        }
      ],
      "source": [
        "model.fit(training_set,\n",
        "          batch_size=128,\n",
        "          steps_per_epoch = 25,\n",
        "          epochs=1,\n",
        "          verbose=1,\n",
        "          validation_data = test_set)"
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "model.save(ibm_model.h5)"
      ],
      "metadata": {
        "id": "tELntg2g8R4-"
      },
      "execution_count": null,
      "outputs": []
    }
  ]
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 {
#       2   "nbformat": 4,
#       3   "nbformat_minor": 0,
#       4   "metadata": {
#       5     "colab": {
#       6       "provenance": []
#       7     },
#       8     "kernelspec": {
#       9       "name": "python3",
#      10       "display_name": "Python 3"
#      11     },
#      12     "language_info": {
#      13       "name": "python"
#      14     }
#      15   },
#      16   "cells": [
#      17     {
#      18       "cell_type": "code",
#      19       "source": [
#      20         "from google.colab import drive\n",
#      21         "drive.mount('/content/drive')"
#      22       ],
#      23       "metadata": {
#      24         "id": "zLesVkvRQiZU",
#      25         "colab": {
#      26           "base_uri": "https://localhost:8080/"
#      27         },
#      28         "outputId": "2ac7bfb5-10e6-4d62-c716-7398800a9a4f"
#      29       },
#      30       "execution_count": 1,
#      31       "outputs": [
#      32         {
#      33           "output_type": "stream",
#      34           "name": "stdout",
#      35           "text": [
#      36             "Mounted at /content/drive\n"
#      37           ]
#      38         }
#      39       ]
#      40     },
#      41     {
#      42       "cell_type": "code",
#      43       "source": [
#      44         "import os\n",
#      45         "import numpy as np\n",
#      46         "import matplotlib.pyplot as plt\n",
#      47         "\n",
#      48         "images = \"/content/drive/MyDrive/archive (3).zip (Unzipped Files)/IBM Dataset/gaussian_filtered_images\"\n",
#      49         "\n",
#      50         "folders = os.listdir(images)\n",
#      51         "print(folders)"
#      52       ],
#      53       "metadata": {
#      54         "colab": {
#      55           "base_uri": "https://localhost:8080/"
#      56         },
#      57         "id": "c753b-tyjxE1",
#      58         "outputId": "750306e7-14f1-4e80-ea24-a9991ad99df8"
#      59       },
#      60       "execution_count": 2,
#      61       "outputs": [
#      62         {
#      63           "output_type": "stream",
#      64           "name": "stdout",
#      65           "text": [
#      66             "['Mild', 'Moderate', 'No_DR', 'Proliferate_DR', 'Severe']\n"
#      67           ]
#      68         }
#      69       ]
#      70     },
#      71     {
#      72       "cell_type": "code",
#      73       "source": [
#      74         "image_data = []\n",
#      75         "labels = []\n",
#      76         "label_dict = {\n",
#      77         "    'No_DR':1,\n",
#      78         "    'Mild':2,\n",
#      79         "    'Moderate':3,\n",
#      80         "    'Proliferate_DR':4,\n",
#      81         "    'Severe':5\n",
#      82         "\n",
#      83         "}"
#      84       ],
#      85       "metadata": {
#      86         "id": "arIOwNihj61t"
#      87       },
#      88       "execution_count": 3,
#      89       "outputs": []
#      90     },
#      91     {
#      92       "cell_type": "code",
#      93       "source": [
#      94         "trainPath=r\"/content/drive/MyDrive/archive (3).zip (Unzipped Files)/IBM Dataset/gaussian_filtered_images\"\n",
#      95         "testPath=r\"/content/drive/MyDrive/archive (3).zip (Unzipped Files)/IBM Dataset/gaussian_filtered_images\""
#      96       ],
#      97       "metadata": {
#      98         "id": "DGUWBEoOlp2Y"
#      99       },
#     100       "execution_count": 4,
#     101       "outputs": []
#     102     },
#     103     {
#     104       "cell_type": "code",
#     105       "source": [
#     106         "from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img\n",
#     107         "from glob import glob\n",
#     108         "import numpy as np\n",
#     109         "import matplotlib.pyplot as plt"
#     110       ],
#     111       "metadata": {
#     112         "id": "ZfoFxp0-lv0M"
#     113       },
#     114       "execution_count": 6,
#     115       "outputs": []
#     116     },
#     117     {
#     118       "cell_type": "code",
#     119       "source": [
#     120         "import tensorflow as tf\n",
#     121         "from keras_preprocessing.image import load_img\n",
#     122         "from keras_preprocessing.image import img_to_array\n",
#     123         "from keras_preprocessing.image import array_to_img\n",
#     124         "import PIL\n",
#     125         "import tensorflow as tf\n",
#     126         "import pathlib\n",
#     127         "import matplotlib.pyplot as plt\n",
#     128         "train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255,\n",
#     129         "                                   shear_range=0.1,\n",
#     130         "                                   zoom_range=0.1,\n",
#     131         "                                   horizontal_flip=True)\n",
#     132         "\n",
#     133         "test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255,\n",
#     134         "                                   shear_range=0.1,\n",
#     135         "                                   zoom_range=0.1,\n",
#     136         "                                   horizontal_flip=True)\n",
#     137         "training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/archive (3).zip (Unzipped Files)/IBM Dataset/gaussian_filtered_images',\n",
#     138         "                                                 target_size = (299, 299),\n",
#     139         "                                                 batch_size = 32,\n",
#     140         "                                                 class_mode = 'categorical')\n",
#     141         "test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/archive (3).zip (Unzipped Files)/IBM Dataset/gaussian_filtered_images',\n",
#     142         "                                                 target_size = (299, 299),\n",
#     143         "                                                 batch_size = 32,\n",
#     144         "                                                 class_mode = 'categorical')"
#     145       ],
#     146       "metadata": {
#     147         "id": "XNjTXua5lz4K",
#     148         "colab": {
#     149           "base_uri": "https://localhost:8080/"
#     150         },
#     151         "outputId": "2fa363eb-52ba-41c6-be9a-7b47023dee07"
#     152       },
#     153       "execution_count": 7,
#     154       "outputs": [
#     155         {
#     156           "output_type": "stream",
#     157           "name": "stdout",
#     158           "text": [
#     159             "Found 3672 images belonging to 5 classes.\n",
#     160             "Found 3672 images belonging to 5 classes.\n"
#     161           ]
#     162         }
#     163       ]
#     164     },
#     165     {
#     166       "cell_type": "code",
#     167       "source": [
#     168         "from tensorflow.keras.models import Sequential\n",
#     169         "from tensorflow.keras.layers import Conv2D\n",
#     170         "from tensorflow.keras.layers import MaxPooling2D\n",
#     171         "from tensorflow.keras.layers import Flatten\n",
#     172         "from tensorflow.keras.layers import Dense\n",
#     173         "from tensorflow.keras.models import Model, Sequential\n",
#     174         "from tensorflow.keras.preprocessing.image import ImageDataGenerator\n",
#     175         "from tensorflow.keras.optimizers import SGD\n",
#     176         "from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D , Flatten\n",
#     177         "from tensorflow.keras.losses import categorical_crossentropy\n",
#     178         "from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping\n",
#     179         "from tensorflow.keras import metrics"
#     180       ],
#     181       "metadata": {
#     182         "id": "hsxhXPgdl15t"
#     183       },
#     184       "execution_count": 31,
#     185       "outputs": []
#     186     },
#     187     {
#     188       "cell_type": "code",
#     189       "source": [
#     190         "from tensorflow.keras.applications.vgg16 import VGG16\n",
#     191         "from tensorflow.keras.applications.vgg16 import preprocess_input\n",
#     192         "vgg16 = VGG16(weights='imagenet')\n",
#     193         "vgg16.summary()\n",
#     194         "\n",
#     195         "x  = vgg16.get_layer('fc2').output\n",
#     196         "prediction = Dense(5, activation='softmax', name='predictions')(x)\n",
#     197         "\n",
#     198         "model = Model(inputs=vgg16.input, outputs=prediction)"
#     199       ],
#     200       "metadata": {
#     201         "id": "fD1rbqoemLq_",
#     202         "colab": {
#     203           "base_uri": "https://localhost:8080/"
#     204         },
#     205         "outputId": "9fd10b79-d41f-44d6-819a-4379712e07b7"
#     206       },
#     207       "execution_count": 32,
#     208       "outputs": [
#     209         {
#     210           "output_type": "stream",
#     211           "name": "stdout",
#     212           "text": [
#     213             "Model: \"vgg16\"\n",
#     214             "_________________________________________________________________\n",
#     215             " Layer (type)                Output Shape              Param #   \n",
#     216             "=================================================================\n",
#     217             " input_5 (InputLayer)        [(None, 224, 224, 3)]     0         \n",
#     218             "                                                                 \n",
#     219             " block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792      \n",
#     220             "                                                                 \n",
#     221             " block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928     \n",
#     222             "                                                                 \n",
#     223             " block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0         \n",
#     224             "                                                                 \n",
#     225             " block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856     \n",
#     226             "                                                                 \n",
#     227             " block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584    \n",
#     228             "                                                                 \n",
#     229             " block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0         \n",
#     230             "                                                                 \n",
#     231             " block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168    \n",
#     232             "                                                                 \n",
#     233             " block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080    \n",
#     234             "                                                                 \n",
#     235             " block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080    \n",
#     236             "                                                                 \n",
#     237             " block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0         \n",
#     238             "                                                                 \n",
#     239             " block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160   \n",
#     240             "                                                                 \n",
#     241             " block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808   \n",
#     242             "                                                                 \n",
#     243             " block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808   \n",
#     244             "                                                                 \n",
#     245             " block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0         \n",
#     246             "                                                                 \n",
#     247             " block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808   \n",
#     248             "                                                                 \n",
#     249             " block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808   \n",
#     250             "                                                                 \n",
#     251             " block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808   \n",
#     252             "                                                                 \n",
#     253             " block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0         \n",
#     254             "                                                                 \n",
#     255             " flatten (Flatten)           (None, 25088)             0         \n",
#     256             "                                                                 \n",
#     257             " fc1 (Dense)                 (None, 4096)              102764544 \n",
#     258             "                                                                 \n",
#     259             " fc2 (Dense)                 (None, 4096)              16781312  \n",
#     260             "                                                                 \n",
#     261             " predictions (Dense)         (None, 1000)              4097000   \n",
#     262             "                                                                 \n",
#     263             "=================================================================\n",
#     264             "Total params: 138,357,544\n",
#     265             "Trainable params: 138,357,544\n",
#     266             "Non-trainable params: 0\n",
#     267             "_________________________________________________________________\n"
#     268           ]
#     269         }
#     270       ]
#     271     },
#     272     {
#     273       "cell_type": "code",
#     274       "source": [
#     275         "checkpoint = ModelCheckpoint(\"ibm_model.h5\", monitor='val_accuracy', verbose=1, \n",
#     276         "                             save_best_only=True, save_weights_only=False, mode='auto')\n",
#     277         "early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='auto')"
#     278       ],
#     279       "metadata": {
#     280         "id": "GsETH7EAyGG5"
#     281       },
#     282       "execution_count": 33,
#     283       "outputs": []
#     284     },
#     285     {
#     286       "cell_type": "code",
#     287       "source": [
#     288         "for layer in model.layers:\n",
#     289         "  layer.trainable  = False  "
#     290       ],
#     291       "metadata": {
#     292         "id": "zb6yVZ4OmVHK"
#     293       },
#     294       "execution_count": 34,
#     295       "outputs": []
#     296     },
#     297     {
#     298       "cell_type": "code",
#     299       "source": [
#     300         "from keras import losses \n",
#     301         "from keras import optimizers \n",
#     302         "from keras import metrics "
#     303       ],
#     304       "metadata": {
#     305         "id": "Y88D6nJvmatF"
#     306       },
#     307       "execution_count": 35,
#     308       "outputs": []
#     309     },
#     310     {
#     311       "cell_type": "code",
#     312       "source": [
#     313         "model.compile(loss = 'mean_squared_error',  \n",
#     314         "   optimizer = 'sgd', metrics = [metrics.categorical_accuracy])"
#     315       ],
#     316       "metadata": {
#     317         "id": "alxJXppy5LRs"
#     318       },
#     319       "execution_count": 36,
#     320       "outputs": []
#     321     },
#     322     {
#     323       "cell_type": "code",
# --> 324       "execution_count": null,
#     325       "metadata": {
#     326         "colab": {
#     327           "background_save": true,
#     328           "base_uri": "https://localhost:8080/"
#     329         },
#     330         "id": "92h-avlJzrX0",
#     331         "outputId": "b87f2c9d-9a95-4d26-8f99-477300cd5e5b"
#     332       },
#     333       "outputs": [
#     334         {
#     335           "name": "stdout",
#     336           "output_type": "stream",
#     337           "text": [
#     338             "25/25 [==============================] - ETA: 0s - loss: 0.1621 - categorical_accuracy: 0.0938  "
#     339           ]
#     340         }
#     341       ],
#     342       "source": [
#     343         "model.fit(training_set,\n",
#     344         "          batch_size=128,\n",
#     345         "          steps_per_epoch = 25,\n",
#     346         "          epochs=1,\n",
#     347         "          verbose=1,\n",
#     348         "          validation_data = test_set)"
#     349       ]
#     350     },
#     351     {
#     352       "cell_type": "code",
#     353       "source": [
#     354         "model.save(ibm_model.h5)"
#     355       ],
#     356       "metadata": {
#     357         "id": "tELntg2g8R4-"
#     358       },
#     359       "execution_count": null,
#     360       "outputs": []
#     361     }
#     362   ]
#     363 }
#
# NameError: name 'null' is not defined
